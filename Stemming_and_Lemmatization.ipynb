# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
stemmer = PorterStemmer()

# %%
sentence = "The runs were running along with the runner through the runs"

# %%
tokens = word_tokenize(sentence)
print(tokens)
# Out:
# ['The', 'runs', 'were', 'running', 'along', 'with', 'the', 'runner', 'through', 'the', 'runs']

# %%
stemmed_words = [stemmer.stem(word) for word in tokens]
print(stemmed_words)
# Out:
# ['the', 'run', 'were', 'run', 'along', 'with', 'the', 'runner', 'through', 'the', 'run']

# %%
# Lemmatization

import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
lemmatizer = WordNetLemmatizer()

# %%
# Define sentence here

sentence = "This is an example sentence for tokenization,running."
tokens = word_tokenize(sentence)
print(tokens)
# Out:
# ['This', 'is', 'an', 'example', 'sentence', 'for', 'tokenization', ',', 'running', '.']

# %%
lemmatized_words = [lemmatizer.lemmatize(word,pos = 'v') for word in tokens]
print(lemmatized_words)
# Out:
# ['This', 'be', 'an', 'example', 'sentence', 'for', 'tokenization', ',', 'run', '.']

# %%
import spacy

# load the English model
nlp = spacy.load("en_core_web_sm")

# your sentence
text = "The children are playing with the mice"

doc = nlp(text)

# print each token and its lemma
for token in doc:
    print(token.text, "→", token.lemma_)
# Out:
# The → the
# children → child
# are → be
# playing → play
# with → with
# the → the
# mice → mouse
